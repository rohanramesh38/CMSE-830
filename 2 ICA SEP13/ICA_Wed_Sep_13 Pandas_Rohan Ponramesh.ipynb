# %% [markdown]
# Put your name here:
# * Rohan
#
#
# Put the names of the people you worked with here:
# * sandhya
# * edmond
# * ragavi
#
#
# Our group divided the datasets according to (see instructions below):

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as plt

# uncomment this if you want to see more datasets:
# sns.get_dataset_names()

# %%
df_peng = sns.load_dataset("penguins")
df_iris = sns.load_dataset("iris")
df_mpg = sns.load_dataset("mpg")
df_tita = sns.load_dataset("titanic")

df_tita.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %% [markdown]
# ____
#
# ## <font color=FFBB00> Pandas ICA </font>
# ____
#
# So that you don't get too used to a given dataset, we have opened four above. You have some options:
# * each person in your group chooses their own dataset,
# * you use as many datasets as there are people in your group, but you all work on them together,
# * or, if your group is very large, use at least four datasets.

# %% [markdown]
# ____
# ## Tip
# ____
#
# Pandas is a very large library. Even if I walked you through each and everything it did, you would have forgotten most of it by the time we reached the end next year.
#
# It is therefore better for you to master the most basic, commonly-used operations and know where to look up more complex data science manipulations.
#
# Of course, perhaps the best place to start is the `Pandas` [documentation itself](https://pandas.pydata.org/).
#
# Over time, you will find little gems that really organize how to get stuff done with Pandas.
#
# Bookmark this webpage!

# %% [markdown]
# ___
# # IDA
# ___
#
# ## [`.head()`](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.head.html) & [`.tail()`](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.tail.html)
# We are going to start with some simple inspections of the datasets. Inspect all of your chosen datasets using `.head()`. Be sure to vary the number of rows you look at. (That is, what can go into the parentheses?)
#
# ✍️ In a markdown cell, discuss any issues you see with the data.

# %%
df_tita
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# Before we get too far, let's explore various ways we can display a dataframe. Of course, we can simply type the name, as in `df_iris`, and press shift-enter. The notebook shows us the top and bottom of the notebook, with the middle not shown. We saw above how to see the top, using `.head()`. Of course, we can also see just the bottom using `.tail()`.
#
# ✍️ Try using `.tail()` so that you can see what it does in comparison to the two other approaches.

# %% [markdown]
# ## [`.style`](https://pandas.pydata.org/docs/user_guide/style.html)
#
# Let's have some fun stylizing our dataframe! Go to [this webpage](https://pandas.pydata.org/docs/user_guide/style.html) and read what is there.
#
# ✍️ With your group, spend some time trying various options for the different datasets. If you are working on the same dataset over a long period of time, this will help keep your mind focused on the organizational structure of your data. Show several examples of how `style` can be used.
#
# Discuss with your group members creative ways to use color in a dataframe to improve your data science workflow.
#
# Also, notice that you can generate long "dot chains" in `Pandas`. Here is a simple example to get you started. Here I highlight the non-numeric data.

# %%
df_peng.head(10).style.set_properties(**{'background-color': 'green'}, subset=['species']).set_properties(**{'background-color': 'blue'}, subset=['sex']).set_properties(**{'background-color': 'yellow'}, subset=['island'])
# Out:
# <style type="text/css">
# #T_bd12e_row0_col0, #T_bd12e_row1_col0, #T_bd12e_row2_col0, #T_bd12e_row3_col0, #T_bd12e_row4_col0, #T_bd12e_row5_col0, #T_bd12e_row6_col0, #T_bd12e_row7_col0, #T_bd12e_row8_col0, #T_bd12e_row9_col0 {
#   background-color: green;
# }
# #T_bd12e_row0_col1, #T_bd12e_row1_col1, #T_bd12e_row2_col1, #T_bd12e_row3_col1, #T_bd12e_row4_col1, #T_bd12e_row5_col1, #T_bd12e_row6_col1, #T_bd12e_row7_col1, #T_bd12e_row8_col1, #T_bd12e_row9_col1 {
#   background-color: yellow;
# }
# #T_bd12e_row0_col6, #T_bd12e_row1_col6, #T_bd12e_row2_col6, #T_bd12e_row3_col6, #T_bd12e_row4_col6, #T_bd12e_row5_col6, #T_bd12e_row6_col6, #T_bd12e_row7_col6, #T_bd12e_row8_col6, #T_bd12e_row9_col6 {
#   background-color: blue;
# }
# </style>
# <table id="T_bd12e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bd12e_level0_col0" class="col_heading level0 col0" >species</th>
# ...

# %% [markdown]
# ## [`.isna()`](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.isna.html)
#
# You will soon see that data science relies heavily on Boolean variables. The reason for this is simple: a very common operation is testing some aspect of your data. _Is this true? Is that true? Is this greater than that? Is this between this and that_? You get the idea: there are **many** questions we want to ask that have an answer "yes" or "no".
#
# Or, in a computer: "true" or "false".
#
# ✍🏻 Take all of your datasets and add `isna()` to the end of the name (e.g., `df_tita.isna()`). What do you get? Discuss what you see. In particular, among the datasets you looked at above that had potential problems, what does the output tell you?

# %%
df_tita.isna()
# Out:
#      survived  pclass    sex    age  sibsp  parch   fare  embarked  class  \
# 0       False   False  False  False  False  False  False     False  False
# 1       False   False  False  False  False  False  False     False  False
# 2       False   False  False  False  False  False  False     False  False
# 3       False   False  False  False  False  False  False     False  False
# 4       False   False  False  False  False  False  False     False  False
# ..        ...     ...    ...    ...    ...    ...    ...       ...    ...
# 886     False   False  False  False  False  False  False     False  False
# 887     False   False  False  False  False  False  False     False  False
# 888     False   False  False   True  False  False  False     False  False
# 889     False   False  False  False  False  False  False     False  False
# 890     False   False  False  False  False  False  False     False  False
#
#        who  adult_male   deck  embark_town  alive  alone
# ...

# %%
df_tita.isna().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %% [markdown]
# ## [`.isnull()`](https://pandas.pydata.org/docs/reference/api/pandas.isnull.html)
#
# ✍🏻 Using the internet, figure out what the difference is between `isna()` and `isnull()`. Put your answer in a markdown cell.

# %%
df_tita.isnull()
# Out:
#      survived  pclass    sex    age  sibsp  parch   fare  embarked  class  \
# 0       False   False  False  False  False  False  False     False  False
# 1       False   False  False  False  False  False  False     False  False
# 2       False   False  False  False  False  False  False     False  False
# 3       False   False  False  False  False  False  False     False  False
# 4       False   False  False  False  False  False  False     False  False
# ..        ...     ...    ...    ...    ...    ...    ...       ...    ...
# 886     False   False  False  False  False  False  False     False  False
# 887     False   False  False  False  False  False  False     False  False
# 888     False   False  False   True  False  False  False     False  False
# 889     False   False  False  False  False  False  False     False  False
# 890     False   False  False  False  False  False  False     False  False
#
#        who  adult_male   deck  embark_town  alive  alone
# ...

# %%
df_tita.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df_tita2=df_tita.head()[::]
df_tita2
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df_tita2.at[2,"sex"]=None
df_tita2
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3    None  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df_tita2.at[3,"sex"]=np.NaN
df_tita2
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3    None  26.0      0      0   7.9250        S  Third
# 3         1       1     NaN  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
print(df_tita2.isna().sum().sex,", ",df_tita2.isnull().sum().sex)
# Out:
# 2 ,  2

# %% [markdown]
# > Difference between **isna() and isnull()**
# > * both used to detect missing values
# > * both returns boolean dataframe of the same dimension of df operated on
# > * both do not detect empty strings ''
# > * if a cell returns True while calling isna(), the data is **Null** or **Missing**, or **None** or **Numpy.Nan**
# > * both have attributes to consider numpy.inf as Nan value

# %% [markdown]
# in the titanic dataset there are 688 nan values for the deck and 177 nan values for the age

# %% [markdown]
# ## [`.corr()`](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.corr.html) & [`.describe()`](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.describe.html)
#
# Looking ahead to getting quick statistics from our dataset, we have already looked at `.describe`. ✍🏻 Practice with `.describe()` to be sure everyone in your groups knows what it can tell you.
#
# ✍🏻 Next, try `.corr` with all of our chosen datasets. Discuss what your group sees in a markdown cell. In particular: what does `.corr()` return? What are the rows? What are the colulmns? Is there a connection to Seaborn's `pairplot`? Try several of the options (e.g., Spearman, Kendall, etc.)

# %%
df_tita.corr()
# Out:
# /var/folders/rw/0tvxrjxd6xgg15ts3dc0z8p80000gn/T/ipykernel_9749/2400322701.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_tita.corr()
#             survived    pclass       age     sibsp     parch      fare  \
# survived    1.000000 -0.338481 -0.077221 -0.035322  0.081629  0.257307
# pclass     -0.338481  1.000000 -0.369226  0.083081  0.018443 -0.549500
# age        -0.077221 -0.369226  1.000000 -0.308247 -0.189119  0.096067
# sibsp      -0.035322  0.083081 -0.308247  1.000000  0.414838  0.159651
# parch       0.081629  0.018443 -0.189119  0.414838  1.000000  0.216225
# fare        0.257307 -0.549500  0.096067  0.159651  0.216225  1.000000
# adult_male -0.557080  0.094035  0.280328 -0.253586 -0.349943 -0.182024
# alone      -0.203367  0.135207  0.198270 -0.584471 -0.583398 -0.271832
#
# ...

# %%
sns.pairplot(df_tita.corr())
# Out:
# /var/folders/rw/0tvxrjxd6xgg15ts3dc0z8p80000gn/T/ipykernel_9749/3019141021.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.pairplot(df_tita.corr())

# %%
sns.pairplot(df_tita)
# Out:
# <__array_function__ internals>:200: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:200: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.

# %% [markdown]
# > The corr() methods provides the linear correlation coeffecient between the columns,
# Correlation coefficients are used to assess the strength of associations between variables.
# >few findings In the titanic data set there is
# > * negative correlation between sibsp and alone
# > * negative correlation between parch and alone
# > * positive correlation between parch and sibsp

# %% [markdown]
# ___
# ## <font color=#00BBFF> Doing Stuff: Moving Beyond IDA and EDA </font>
# ___
#
# ## Row and Column Selection
#
#
# Let's practice basic row and column selections. There are many reasons for these operations, including
# * reducing the size of the dataset so that you can do quick operations while you get things to work (then, you use the full dataset for the final result)
# * you simply don't want the distraction of columns you will never use,
# * some operations don't work on all columns (some of you noticed an issue with color-coding numbers when some columns contained strings),
# * and so on....
#
# For this part of the ICA, we assume you know in advance which rows and columns you want. Below, we will use mask-type operations.
#
# ✍️ With your chosen datasets, invent operations you might want to do in the real world. Each person in your group can pick something different. For example, you only want columns with floats; or, you only want the first $4$ columns. Try each of these:
# * select a single column,
# * select a subset of columns, using a list of column names (the syntax is: `age_sex = titanic[["Age", "Sex"]]`)
# * columns also have an index, so try both of these approaches:
#   - df. iloc[:, [0,1,3]]
#   - df. iloc[:, 0:3]
#
# Discuss with your group what these do and how you would use them. Previously, we thought about `iloc` for selecting rows: here it is used for columns. If you don't know this already, in Python the `:` is used to mean "all". Here, you would read this syntax as "_all rows and columns [0,1,3]_". (Note that your columns may have more meaningful names, but you can still use integers.)
#
# Show your work and summarize what you did in a markdown cell.
#
# ✍️  As you work, be sure to practice the basic Pandas attributes and methods on your new dataframes:
# * `.shape`
# * `.describe`
# * `.head` and `.tail`
# * `.index`
# * `.values`
# * `.dtypes`
# * etc....
#
# ✍️  One important issue to also pay attention to: when you do something to a dataframe, does it change the dataframe itself, or does it produce a new dataframe (and thereby preserve the original)? This is very important to keep track of: you don't want to lose your data by overwriting it, and you also don't want to generate so many new dataframes you lose track of them. Put a discussion of what you find in a markdown cell.
#
# ✍️ Figure out what this syntax does, discuss within your group and show an example:
#
# `df_tita.iloc[4:14, 1:3]`

# %% [markdown]
# > iloc and loc can be used to extract rows and columns by slicing the data frame

# %%
df_small=df_tita.loc[10:100, ("age","fare","class")]
df_small
# Out:
#       age     fare   class
# 10    4.0  16.7000   Third
# 11   58.0  26.5500   First
# 12   20.0   8.0500   Third
# 13   39.0  31.2750   Third
# 14   14.0   7.8542   Third
# ..    ...      ...     ...
# 96   71.0  34.6542   First
# 97   23.0  63.3583   First
# 98   34.0  23.0000  Second
# 99   34.0  26.0000  Second
# 100  28.0   7.8958   Third
#
# [91 rows x 3 columns]

# %%
df_small['class']=df_small['class'].str[0].str.upper().map({'F':1, 'S':2,'T':3})

# %%
df_small.shape
# Out:
# (91, 3)

# %%
df_small.describe()
# Out:
#              age        fare      class
# count  70.000000   91.000000  91.000000
# mean   27.390429   29.554397   2.417582
# std    15.315261   42.372776   0.803685
# min     0.830000    7.225000   1.000000
# 25%    18.250000    8.050000   2.000000
# 50%    26.000000   15.500000   3.000000
# 75%    34.000000   31.331250   3.000000
# max    71.000000  263.000000   3.000000

# %%
sns.pairplot(df_small.corr())

# %%
sns.pairplot(df_small)

# %%
df_tita.dropna()

df_tita
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3    None  26.0      0      0   7.9250        S   Third
# 3           1       1     NaN  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
print(list(df_tita.columns))
# to get columns with int64 values seperately
new_df= pd.DataFrame({})
for col in list(df_tita.columns):
    try:
        
        print(np.dtype(df_tita[col]))
        if(np.dtype(df_tita[col]) == 'int64'):
            print(col)
            new_df[col]=df_tita[col][::]
    except:
        print("")
new_df
# Out:
# ['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare', 'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town', 'alive', 'alone']
# int64
# survived
# int64
# pclass
# object
# float64
# int64
# sibsp
# int64
# parch
# float64
# object
#
# object
# bool
#
# object
# object
# bool
#      survived  pclass  sibsp  parch
# 0           0       3      1      0
# 1           1       1      1      0
# 2           1       3      0      0
# 3           1       1      1      0
# 4           0       3      0      0
# ..        ...     ...    ...    ...
# 886         0       2      0      0
# 887         1       1      0      0
# 888         0       3      1      2
# 889         1       1      0      0
# 890         0       3      0      0
#
# [891 rows x 4 columns]

# %% [markdown]
# _____
#
# 👍🏻👍🏻👍🏻
#
# Congrats! You have reached the end.
#
# Don't forget to put your name at the top, and the names of the people you worked with.
#
# Upload the notebook into D2L. If you have any trouble, contact Mahyar through Slack.
